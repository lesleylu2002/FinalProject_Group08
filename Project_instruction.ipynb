# %%
import os
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Constants
TLC_URL = "https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page"
YELLOW_TAXI_DIR = "./yellow_taxi_data"
UBER_DATA_DIR = "./uber_data"
TAXI_ZONES_DIR = "./taxi_zones"
TAXI_ZONES_SHAPEFILE = f"{TAXI_ZONES_DIR}/taxi_zones.parquet"

# Ensure directories exist
os.makedirs(YELLOW_TAXI_DIR, exist_ok=True)
os.makedirs(UBER_DATA_DIR, exist_ok=True)
os.makedirs(TAXI_ZONES_DIR, exist_ok=True)

# %%
# Downloading
def fetch_and_download_data(base_url, regex_pattern, save_dir):
    """
    Downloads Parquet files based on a regex pattern.
    """
    os.makedirs(save_dir, exist_ok=True)
    response = requests.get(base_url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')

    # Filter links by regex for 2020-2024 data
    links = soup.find_all("a", href=re.compile(regex_pattern))
    for link in links:
        file_url = link["href"]
        if not file_url.startswith("http"):
            file_url = f"https:{file_url}"
        file_name = file_url.split("/")[-1]
        save_path = os.path.join(save_dir, file_name)

        if not os.path.exists(save_path):
            print(f"Downloading {file_name}...")
            file_response = requests.get(file_url, stream=True)
            with open(save_path, "wb") as f:
                for chunk in file_response.iter_content(chunk_size=1024):
                    if chunk:
                        f.write(chunk)
            print(f"Saved {file_name} to {save_dir}.")
        else:
            print(f"{file_name} already exists. Skipping download.")

# %%
# Sampling
def calculate_sample_size(population, confidence_level=0.95, margin_of_error=0.05):
    """
    Calculate sample size using Cochran's formula.
    """
    z = (2 * (1 - confidence_level)) ** -0.5
    p = 0.5
    numerator = (z ** 2) * p * (1 - p)
    denominator = margin_of_error ** 2
    initial_sample_size = numerator / denominator

    if population:
        adjusted_sample_size = initial_sample_size / (1 + (initial_sample_size - 1) / population)
        return int(adjusted_sample_size + 0.5)
    return int(initial_sample_size + 0.5)

# %%
# Cleaning
def get_and_clean_taxi_month(url, sample_size=None):
    """
    Load, clean, and optionally sample a single month's taxi data.
    """
    import pyarrow.parquet as pq

    # Load the Parquet file
    try:
        df = pd.read_parquet(url, engine='pyarrow', use_legacy_dataset=True)
    except Exception as e:
        print(f"Error reading Parquet file: {url}. Error: {e}")
        return pd.DataFrame()  # Return empty DataFrame on failure

    # Cleaning logic
    df = df[df["PULocationID"].notnull() & df["DOLocationID"].notnull()]
    df = df[df["trip_distance"] > 0]

    # Sampling logic
    if sample_size and sample_size < len(df):
        df = df.sample(n=sample_size)

    return df

# %%
def get_and_clean_taxi_data(parquet_urls, sample_size=None):
    """
    Process multiple Parquet files, clean, and optionally sample the data.
    """
    all_taxi_data = []

    for url in parquet_urls:
        if not os.path.exists(url):
            print(f"File not found: {url}. Skipping...")
            continue

        df = get_and_clean_taxi_month(url, sample_size)
        if not df.empty:
            all_taxi_data.append(df)

    if all_taxi_data:
        taxi_data = pd.concat(all_taxi_data, ignore_index=True)
    else:
        taxi_data = pd.DataFrame()

    return taxi_data

# %%
# Taxi Zone Shapefile
def load_taxi_zones(shapefile):
    """
    Load taxi zone shapefile data as a GeoDataFrame.
    """
    import geopandas as gpd
    try:
        taxi_zones = gpd.read_file(shapefile)
        print("Taxi Zones loaded successfully.")
        return taxi_zones
    except Exception as e:
        print(f"Error loading Taxi Zones: {e}")
        raise

# %%
def main():
    # Download data for 2020-2024
    fetch_and_download_data(TLC_URL, r"yellow_tripdata_(202[0-4]-\d{2})\.parquet", YELLOW_TAXI_DIR)
    fetch_and_download_data(TLC_URL, r"fhvhv_tripdata_(202[0-4]-\d{2})\.parquet", UBER_DATA_DIR)

    # Calculate sample sizes
    yellow_sample_size = calculate_sample_size(population=1000000)
    uber_sample_size = calculate_sample_size(population=500000)

    print(f"Yellow Taxi sample size: {yellow_sample_size}")
    print(f"Uber sample size: {uber_sample_size}")

    # Process Yellow Taxi data
    yellow_data_files = [os.path.join(YELLOW_TAXI_DIR, f) for f in os.listdir(YELLOW_TAXI_DIR) if f.endswith(".parquet")]
    print(f"Yellow Taxi files: {yellow_data_files}")

    yellow_data = get_and_clean_taxi_data(yellow_data_files, sample_size=yellow_sample_size)
    print(f"Processed Yellow Taxi data shape: {yellow_data.shape}")

    # Process Uber data
    uber_data_files = [os.path.join(UBER_DATA_DIR, f) for f in os.listdir(UBER_DATA_DIR) if f.endswith(".parquet")]
    print(f"Uber files: {uber_data_files}")

    uber_data = get_and_clean_taxi_data(uber_data_files, sample_size=uber_sample_size)
    print(f"Processed Uber data shape: {uber_data.shape}")

# %%
if __name__ == "__main__":
    main()
# Out:
# yellow_tripdata_2024-01.parquet  already exists. Skipping download.
# yellow_tripdata_2024-02.parquet  already exists. Skipping download.
# yellow_tripdata_2024-03.parquet  already exists. Skipping download.
# yellow_tripdata_2024-04.parquet already exists. Skipping download.
# yellow_tripdata_2024-05.parquet already exists. Skipping download.
# yellow_tripdata_2024-06.parquet already exists. Skipping download.
# yellow_tripdata_2024-07.parquet already exists. Skipping download.
# yellow_tripdata_2024-08.parquet already exists. Skipping download.
# yellow_tripdata_2023-01.parquet already exists. Skipping download.
# yellow_tripdata_2023-02.parquet already exists. Skipping download.
# yellow_tripdata_2023-03.parquet already exists. Skipping download.
# yellow_tripdata_2023-04.parquet already exists. Skipping download.
# yellow_tripdata_2023-05.parquet  already exists. Skipping download.
# yellow_tripdata_2023-06.parquet already exists. Skipping download.
# yellow_tripdata_2023-07.parquet  already exists. Skipping download.
# yellow_tripdata_2023-08.parquet  already exists. Skipping download.
# yellow_tripdata_2023-09.parquet  already exists. Skipping download.
# yellow_tripdata_2023-10.parquet  already exists. Skipping download.
# yellow_tripdata_2023-11.parquet  already exists. Skipping download.
# yellow_tripdata_2023-12.parquet already exists. Skipping download.
# yellow_tripdata_2022-01.parquet already exists. Skipping download.
# yellow_tripdata_2022-02.parquet already exists. Skipping download.
# yellow_tripdata_2022-03.parquet already exists. Skipping download.
# yellow_tripdata_2022-04.parquet already exists. Skipping download.
# yellow_tripdata_2022-05.parquet already exists. Skipping download.
# yellow_tripdata_2022-06.parquet already exists. Skipping download.
# yellow_tripdata_2022-07.parquet already exists. Skipping download.
# yellow_tripdata_2022-08.parquet already exists. Skipping download.
# yellow_tripdata_2022-09.parquet already exists. Skipping download.
# yellow_tripdata_2022-10.parquet already exists. Skipping download.
# yellow_tripdata_2022-11.parquet already exists. Skipping download.
# yellow_tripdata_2022-12.parquet already exists. Skipping download.
# yellow_tripdata_2021-01.parquet already exists. Skipping download.
# yellow_tripdata_2021-02.parquet already exists. Skipping download.
# yellow_tripdata_2021-03.parquet already exists. Skipping download.
# yellow_tripdata_2021-04.parquet already exists. Skipping download.
# yellow_tripdata_2021-05.parquet already exists. Skipping download.
# yellow_tripdata_2021-06.parquet already exists. Skipping download.
# yellow_tripdata_2021-07.parquet already exists. Skipping download.
# yellow_tripdata_2021-08.parquet already exists. Skipping download.
# yellow_tripdata_2021-09.parquet already exists. Skipping download.
# yellow_tripdata_2021-10.parquet already exists. Skipping download.
# yellow_tripdata_2021-11.parquet already exists. Skipping download.
# yellow_tripdata_2021-12.parquet already exists. Skipping download.
# yellow_tripdata_2020-01.parquet already exists. Skipping download.
# yellow_tripdata_2020-02.parquet already exists. Skipping download.
# yellow_tripdata_2020-03.parquet already exists. Skipping download.
# yellow_tripdata_2020-04.parquet already exists. Skipping download.
# yellow_tripdata_2020-05.parquet already exists. Skipping download.
# yellow_tripdata_2020-06.parquet already exists. Skipping download.
# yellow_tripdata_2020-07.parquet already exists. Skipping download.
# yellow_tripdata_2020-08.parquet already exists. Skipping download.
# yellow_tripdata_2020-09.parquet already exists. Skipping download.
# yellow_tripdata_2020-10.parquet already exists. Skipping download.
# yellow_tripdata_2020-11.parquet already exists. Skipping download.
# yellow_tripdata_2020-12.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-01.parquet  already exists. Skipping download.
# fhvhv_tripdata_2024-02.parquet  already exists. Skipping download.
# fhvhv_tripdata_2024-03.parquet  already exists. Skipping download.
# fhvhv_tripdata_2024-04.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-05.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-06.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-07.parquet already exists. Skipping download.
# fhvhv_tripdata_2024-08.parquet already exists. Skipping download.
# fhvhv_tripdata_2023-01.parquet already exists. Skipping download.
# fhvhv_tripdata_2023-02.parquet already exists. Skipping download.
# fhvhv_tripdata_2023-03.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-04.parquet already exists. Skipping download.
# fhvhv_tripdata_2023-05.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-06.parquet already exists. Skipping download.
# fhvhv_tripdata_2023-07.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-08.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-09.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-10.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-11.parquet  already exists. Skipping download.
# fhvhv_tripdata_2023-12.parquet  already exists. Skipping download.
# fhvhv_tripdata_2022-01.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-02.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-03.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-04.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-05.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-06.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-07.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-08.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-09.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-10.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-11.parquet already exists. Skipping download.
# fhvhv_tripdata_2022-12.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-01.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-02.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-03.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-04.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-05.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-06.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-07.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-08.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-09.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-10.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-11.parquet already exists. Skipping download.
# fhvhv_tripdata_2021-12.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-01.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-02.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-03.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-04.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-05.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-06.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-07.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-08.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-09.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-10.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-11.parquet already exists. Skipping download.
# fhvhv_tripdata_2020-12.parquet already exists. Skipping download.
# Yellow Taxi sample size: 999
# Uber sample size: 998
# Yellow Taxi files: ['./yellow_taxi_data/yellow_tripdata_2023-06.parquet', './yellow_taxi_data/yellow_tripdata_2022-10.parquet', './yellow_taxi_data/yellow_tripdata_2020-03.parquet', './yellow_taxi_data/yellow_tripdata_2021-05.parquet', './yellow_taxi_data/yellow_tripdata_2022-09.parquet', './yellow_taxi_data/yellow_tripdata_2024-04.parquet', './yellow_taxi_data/yellow_tripdata_2020-12.parquet', './yellow_taxi_data/yellow_tripdata_2020-02.parquet', './yellow_taxi_data/yellow_tripdata_2021-04.parquet', './yellow_taxi_data/yellow_tripdata_2022-08.parquet', './yellow_taxi_data/yellow_tripdata_2024-05.parquet', './yellow_taxi_data/yellow_tripdata_2022-01.parquet', './yellow_taxi_data/yellow_tripdata_2022-11.parquet', './yellow_taxi_data/yellow_tripdata_2020-10.parquet', './yellow_taxi_data/yellow_tripdata_2024-07.parquet', './yellow_taxi_data/yellow_tripdata_2021-06.parquet', './yellow_taxi_data/yellow_tripdata_2020-09.parquet', './yellow_taxi_data/yellow_tripdata_2022-03.parquet', './yellow_taxi_data/yellow_tripdata_2023-04.parquet', './yellow_taxi_data/yellow_tripdata_2020-08.parquet', './yellow_taxi_data/yellow_tripdata_2022-02.parquet', './yellow_taxi_data/yellow_tripdata_2022-12.parquet', './yellow_taxi_data/yellow_tripdata_2020-11.parquet', './yellow_taxi_data/yellow_tripdata_2020-01.parquet', './yellow_taxi_data/yellow_tripdata_2024-06.parquet', './yellow_taxi_data/yellow_tripdata_2021-07.parquet', './yellow_taxi_data/yellow_tripdata_2021-02.parquet', './yellow_taxi_data/yellow_tripdata_2021-12.parquet', './yellow_taxi_data/yellow_tripdata_2020-04.parquet', './yellow_taxi_data/yellow_tripdata_2019-01.parquet', './yellow_taxi_data/yellow_tripdata_2022-07.parquet', './yellow_taxi_data/yellow_tripdata_2023-01.parquet', './yellow_taxi_data/yellow_tripdata_2022-06.parquet', './yellow_taxi_data/yellow_tripdata_2021-03.parquet', './yellow_taxi_data/yellow_tripdata_2020-05.parquet', './yellow_taxi_data/yellow_tripdata_2022-04.parquet', './yellow_taxi_data/yellow_tripdata_2021-08.parquet', './yellow_taxi_data/yellow_tripdata_2023-12.parquet', './yellow_taxi_data/yellow_tripdata_2023-02.parquet', './yellow_taxi_data/yellow_tripdata_2021-01.parquet', './yellow_taxi_data/yellow_tripdata_2021-11.parquet', './yellow_taxi_data/yellow_tripdata_2020-07.parquet', './yellow_taxi_data/yellow_tripdata_2021-10.parquet', './yellow_taxi_data/yellow_tripdata_2020-06.parquet', './yellow_taxi_data/yellow_tripdata_2024-08.parquet', './yellow_taxi_data/yellow_tripdata_2022-05.parquet', './yellow_taxi_data/yellow_tripdata_2021-09.parquet', './yellow_taxi_data/yellow_tripdata_2023-03.parquet']
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# Error reading Parquet file: ./yellow_taxi_data/yellow_tripdata_2019-01.parquet. Error: Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# /var/folders/kg/5js8flcn3c138fq2kf35s9vh0000gn/T/ipykernel_37366/385096453.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   taxi_data = pd.concat(all_taxi_data, ignore_index=True)
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parquet.py:274: FutureWarning: Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 8.0.0, and the legacy implementation will be removed in a future version.
#   pa_table = self.api.parquet.read_table(
# Processed Yellow Taxi data shape: (46953, 20)
# Uber files: ['./uber_data/fhvhv_tripdata_2021-03.parquet', './uber_data/fhvhv_tripdata_2020-05.parquet', './uber_data/fhvhv_tripdata_2022-06.parquet', './uber_data/fhvhv_tripdata_2022-07.parquet', './uber_data/fhvhv_tripdata_2023-01.parquet', './uber_data/fhvhv_tripdata_2021-12.parquet', './uber_data/fhvhv_tripdata_2021-02.parquet', './uber_data/fhvhv_tripdata_2020-04.parquet', './uber_data/fhvhv_tripdata_2021-09.parquet', './uber_data/fhvhv_tripdata_2022-05.parquet', './uber_data/fhvhv_tripdata_2024-08.parquet', './uber_data/fhvhv_tripdata_2021-10.parquet', './uber_data/fhvhv_tripdata_2020-06.parquet', './uber_data/fhvhv_tripdata_2021-11.parquet', './uber_data/fhvhv_tripdata_2021-01.parquet', './uber_data/fhvhv_tripdata_2020-07.parquet', './uber_data/fhvhv_tripdata_2021-08.parquet', './uber_data/fhvhv_tripdata_2022-04.parquet', './uber_data/fhvhv_tripdata_2023-02.parquet', './uber_data/fhvhv_tripdata_2022-11.parquet', './uber_data/fhvhv_tripdata_2022-01.parquet', './uber_data/fhvhv_tripdata_2020-02.parquet', './uber_data/fhvhv_tripdata_2020-12.parquet', './uber_data/fhvhv_tripdata_2024-05.parquet', './uber_data/fhvhv_tripdata_2022-08.parquet', './uber_data/fhvhv_tripdata_2021-04.parquet', './uber_data/fhvhv_tripdata_2020-03.parquet', './uber_data/fhvhv_tripdata_2024-04.parquet', './uber_data/fhvhv_tripdata_2022-09.parquet', './uber_data/fhvhv_tripdata_2021-05.parquet', './uber_data/fhvhv_tripdata_2023-06.parquet', './uber_data/fhvhv_tripdata_2022-10.parquet', './uber_data/fhvhv_tripdata_2020-01.parquet', './uber_data/fhvhv_tripdata_2020-11.parquet', './uber_data/fhvhv_tripdata_2021-07.parquet', './uber_data/fhvhv_tripdata_2024-06.parquet', './uber_data/fhvhv_tripdata_2020-08.parquet', './uber_data/fhvhv_tripdata_2023-04.parquet', './uber_data/fhvhv_tripdata_2022-12.parquet', './uber_data/fhvhv_tripdata_2022-02.parquet', './uber_data/fhvhv_tripdata_2020-09.parquet', './uber_data/fhvhv_tripdata_2022-03.parquet', './uber_data/fhvhv_tripdata_2020-10.parquet', './uber_data/fhvhv_tripdata_2021-06.parquet', './uber_data/fhvhv_tripdata_2024-07.parquet']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trip_distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[15], line 24, in main()
#      21 uber_data_files = [os.path.join(UBER_DATA_DIR, f) for f in os.listdir(UBER_DATA_DIR) if f.endswith(".parquet")]
#      22 print(f"Uber files: {uber_data_files}")
# ---> 24 uber_data = get_and_clean_taxi_data(uber_data_files, sample_size=uber_sample_size)
#      25 print(f"Processed Uber data shape: {uber_data.shape}")
#
# Cell In[11], line 12, in get_and_clean_taxi_data(parquet_urls, sample_size)
#       9     print(f"File not found: {url}. Skipping...")
#      10     continue
# ---> 12 df = get_and_clean_taxi_month(url, sample_size)
#      13 if not df.empty:
#      14     all_taxi_data.append(df)
#
# Cell In[9], line 17, in get_and_clean_taxi_month(url, sample_size)
#      15 # Cleaning logic
#      16 df = df[df["PULocationID"].notnull() & df["DOLocationID"].notnull()]
# ---> 17 df = df[df["trip_distance"] > 0]
#      19 # Sampling logic
#      20 if sample_size and sample_size < len(df):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'trip_distance'
